# %% [markdown]
# ## Segmentation Pipeline ##
# **Project**: Artificial Intelligence-Based Cell Survival Colony Counting \
# **Author**: Mona Wang \
# **Supervisors**: Laya Rafiee Sevyeri, Shirin A. Enger
#
# This Jupyter notebook will:
# 1. Segment the colonies based on watershed algorithm
# 1. Output the final colony count
# 1. Output the image of the segmented colony

# %%
## Toggles ##
segment_colonies = True
count_colonies = True
test_accuracy = True

core = False
solidity = False

# %%
## Imports ##
import sys
import math
import numpy as np
import glob
import re

# Image Processing
import cv2 as cv
from skimage import morphology, img_as_ubyte
from skimage.morphology import extrema
from skimage.util import img_as_float64

# For controlling cell execution
from IPython.core.magic import register_cell_magic
from IPython import get_ipython

@register_cell_magic
def skip_if(line, cell):
    if eval(line):
        return
    get_ipython().run_cell(cell)

## Fix the issue of Error #15 "Initializing libiomp5md.dll, but found mk2iomp5md.dll already initialized." ##
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"


## Function for Numerical Ordering ##
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
## Paths ##
''' 
Variables:
    image_dir(str): directory of input data
    image_paths(list): list of all jpg files in the image_dir
    preprocess_path(str): diretory containing intermediaries
    processed_img_path (str): directory containing processed images
    processed_mask_path (str): directory containing generated masks
    processed_overlay_path (str): directory containing overlaid images
'''
mask_path = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'mask_small')
overlay_path = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'overlay')


image_dir = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'img_raw') # input directory
image_paths = glob.glob(os.path.join(image_dir, '*.jpg'))
preprocess_path = os.path.join('.', 'preprocessing') # directory for the intermediaries
processed_img_path = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'img')
processed_mask_path = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'mask_small')
processed_overlay_path = os.path.join('.', 'Data', 'HCT116_Dataset_CV', 'overlay')
segmented_mask_path = os.path.join('.', 'Data', 'HCT116_Dataset', 'mask_small')

## Validation ##
print(f'Number of Images: {len(image_paths)}')
print(f'One sample of Image Name: {image_paths[0]}')
# Out:
# Number of Images: 787
# One sample of Image Name: .\Data\HCT116_Dataset_CV\img_raw\Sample_1-1.jpg

# %% [markdown]
# #### Toggle Additional Functions

# %%
def local_max(img, kernel):
    original_shape = img.shape[0]
    if img.shape[0] % kernel != 0:
        padding = kernel - (img.shape[0] % kernel)
        img = np.pad(img, ((0, padding), (0, padding)), mode='constant', constant_values=0)
    else:
        padding = 0
    out = np.zeros_like(img) # Get the output image
    for i in range(0, img.shape[0], kernel):
        for j in range(0, img.shape[1], kernel):
            if np.mean(img[i+kernel:i+2*kernel, j+kernel: j+2*kernel]) > np.mean(img[i:i+3*kernel, j:j+3*kernel]):
                out[i+kernel:i+2*kernel, j+kernel: j+2*kernel] = img[i+kernel:i+2*kernel, j+kernel:j+2*kernel]
    return out[:original_shape, :original_shape]
            

def solidity(img, thresh):
    '''
        Determining the solid and non-solid blobs and divide them into two masks
        
        Returns:
            mask_non_solid (numpy.ndarray): masks containing non solid blobs
            mask_solid (numpy.ndarray): masks containing solid blobs
    '''

    #####################################
    ## Split by solidity on sureFront1 ##
    #####################################
    '''
        Compute solidity (area/hull_area) and split the objects based on solidity.processed_overlay_path 

        Variables:
            contours(list): list of all object contours in the image.
            contours_solid(list): contours of objects that do not need further segmentation.
            contours_non_solid(list): contours of objects that need further segmentation due to bordering.

    '''
    contours, _ = cv.findContours(img, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE) # detect all objects in sureFront1_inter
    contours_solid=[] # Does not need further segmentation
    contours_non_solid = [] # Need further segmentation
    for contour in contours:
        area = cv.contourArea(contour) # find area of a contour
        hull = cv.convexHull(contour) # find convex hull of a contour
        hull_area = cv.contourArea(hull) # find convex hull area
        if hull_area == 0:
            continue
        solidity = float(area)/hull_area
        if(solidity<thresh and area>2800): #threshold is 0.94
            contours_non_solid.append(contour)
        else:
            contours_solid.append(contour)

    ###########################################
    ## Further process the non-solid objects ##
    ###########################################
    '''
        Variables:
            mask_non_solid(numpy.ndarray): new mask for storing non-solid objects
            mask_solid(numpy.ndarray): new mask for storing solid objects
            sureFront(numpy.ndarray): final sure foreground with all but small objects

    '''
    contours_non_solid = tuple(contours_non_solid)
    contours_solid = tuple(contours_solid)
    mask_non_solid = np.zeros(img.shape, dtype=np.uint8)
    mask_solid = np.zeros(img.shape, dtype=np.uint8)
    cv.drawContours(mask_non_solid, contours_non_solid, contourIdx=-1, color=(255, 255, 255), thickness=cv.FILLED)
    cv.drawContours(mask_solid, contours_solid, contourIdx=-1, color=(255, 255, 255), thickness=cv.FILLED) #split the mask further
    
    return mask_non_solid, mask_solid


def distTrans(img, medianBlurKernel, localMaxKernel, openingKernel):
    # Distance Transform on the non-solid objects
    dist = cv.distanceTransform(img, distanceType=cv.DIST_L2, maskSize=3)
    dist = cv.normalize(dist, None, 255, 0, cv.NORM_MINMAX, cv.CV_8U)
    dist = cv.medianBlur(dist, medianBlurKernel)

    # Find local max from image
    kernel2 = cv.getStructuringElement(cv.MORPH_ELLIPSE, openingKernel)
    mask_non_solid = local_max(dist, localMaxKernel)
    _, mask_non_solid = cv.threshold(mask_non_solid, 1, 255, cv.THRESH_BINARY)
    mask_non_solid = cv.morphologyEx(mask_non_solid, cv.MORPH_OPEN, kernel2, iterations=3)
    # cv.imshow("img", cv.resize(mask_non_solid, (750, 750)))
    # cv.waitKey(0)
    
    return mask_non_solid


def solidity_processing(img, thresh):
    '''
        For segmenting the hard-to-semgent non-solid objects:

        1. Computes the solidity of each detected object
        2. Uses the given threshold of "non-solid" objects and detect all "non-solid" objects
        3. Further processes the "non-solid" objects

    '''    
    mask_non_solid, mask_solid = solidity(img, thresh)

    mask_non_solid = distTrans(mask_non_solid, 35, 12, (15, 15))
    
    mask_non_solid2, mask_solid2 = solidity(mask_non_solid, thresh)
    
    mask_non_solid2 = distTrans(mask_non_solid2, 35, 12, (9, 9))

    sureFront = cv.bitwise_or(cv.bitwise_or(mask_non_solid2, mask_solid2), mask_solid)
    
    return sureFront

# maybe repeat this twice

# %% [markdown]
# #### Part I - Colonies Segmentation
# Colonies are segmented with an augmented divide-conquer watershed algorithm.\
# \
# Main techniques used:
# 1. connectedComponent: separating small colonies from large colonies
# 1. Marker-Based Watershed: segment colonies by watershed, markers generated from sure foreground and background.

# %%
# %%skip_if segment_colonies == False
#
#
# # Directories as sorted list
# mask_dir = sorted(os.listdir(mask_path), key=numericalSort)
#
# # Kernel used for morphological transformation
# kernel = np.ones((3,3), np.uint8)
#
# # Contours of segmentation
# contours_list = {}
#
# for filename_mask in mask_dir:
#     print('Now Segmenting:', filename_mask)
#     filename_overlay = "Overlay" + filename_mask[4:]
#     mask = cv.cvtColor(cv.imread(os.path.join(mask_path, filename_mask)).astype(np.uint8), cv.COLOR_RGB2GRAY) # converting mask to uint8 and grayscale
#     overlay = cv.imread(os.path.join(overlay_path, filename_overlay))
#
#     ###################################################################
#     ## Inverse grayscale of the overlay to threshold the colony core ##
#     ###################################################################
#     '''
#         Variables:
#             overlay_inverse(numpy.ndarray): intermediate threshold image for finding sure foreground and background, the inverse grayscale image of overlay and mask
#             sureBack(numpy.ndarray): sure background, obtained from overlay_inverse
#             sureFront1_inter(numpy.ndarray): intermediate sure background, obtained from overlay_inverse
#             sureFront2_inter(numpy.ndarray): intermediate sure background for keeping small colonies, obtained from overlay_inverse
#
#     '''
#     overlay_org = cv.medianBlur(cv.cvtColor(overlay.copy(), cv.COLOR_BGR2GRAY), 15)
#     overlay_inverse = cv.bitwise_not(overlay_org)
#     overlay_inverse = cv.medianBlur(overlay_inverse, 5)
#     overlay_inverse = cv.bitwise_and(overlay_inverse, mask)
#     # cv.imshow("img", cv.resize(overlay_inverse, (750, 750)))
#     # cv.waitKey(0)
#
#
#     # Binary thresholding
#     if core == True:
#         sureFront1_inter = cv.threshold(overlay_inverse, 239, 255, cv.THRESH_BINARY)[1] #240 # For obtaining sure foreground
#     else:
#         sureFront1_inter = cv.threshold(overlay_inverse, 7, 255, cv.THRESH_BINARY)[1]
#     sureFront2_inter = cv.threshold(overlay_inverse, 7, 255, cv.THRESH_BINARY)[1] #7 # For obtaining small colonies of the sure foreground
#     sureBack = cv.dilate(cv.threshold(overlay_inverse, 115, 255, cv.THRESH_BINARY)[1], kernel, iterations=5) #110 # Sure background
#
#
#     ################################################
#     ## Morphological Transformation on sureFront2 ##
#     ################################################
#     '''
#         Variables:
#             sureFront2_inter(numpy.ndarray): intermediate sure background for keeping small colonies
#             sureFront2(numpy.ndarray): sure background containing only small colonies less than 7000 pixels big
#
#     '''
#     sureFront2_inter = cv.erode(sureFront2_inter, kernel, iterations=8) # use RGB
#     sureFront2_inter = cv.dilate(sureFront2_inter, kernel, iterations=2) # use RGB
#
#
#     # Remove big objects from the mask
#     nb_blobs, mask_separated_blobs, stats, _ = cv.connectedComponentsWithStats(sureFront2_inter)
#     sizes = stats[:, cv.CC_STAT_AREA]
#     sureFront2 = np.zeros_like(mask_separated_blobs)
#     for i in range(1, nb_blobs):
#         if sizes[i] <= 7000 and sizes[i] >= 200: #exclude big objects
#             sureFront2[mask_separated_blobs == i] = 255
#     sureFront2 = img_as_ubyte(sureFront2)
#
#
#     ################################################
#     ## Morphological Transformation on sureFront1 ##
#     ################################################
#     '''
#         Variables:
#             sureFront1_inter(numpy.ndarray): intermediate sure background for keeping small colonies
#             sureFront2(numpy.ndarray): sure background containing only small colonies less than 7000 pixels big
#
#     '''
#     if core == True:
#         temp_kernel = cv.getStructuringElement(cv.MORPH_CROSS, (12, 12))
#         sureFront1_inter = cv.morphologyEx(sureFront1_inter, cv.MORPH_OPEN, temp_kernel)
#         sureFront1 = img_as_ubyte(morphology.remove_small_holes(sureFront1_inter, area_threshold=2000))
#     else:
#         sureFront1 = solidity_processing(sureFront1_inter, 0.94)
#
#
#     ############################
#     ## Marker-based Watershed ##
#     ############################
#     '''
#         Variables:
#             sureFront(numpy.ndarray): final sure foreground.
#             unsure(numpy.ndarray): unsure regions to differentiate foreground and background.
#             markers(numpy.ndarray): markers specifying the regions to flood for watershed.
#             markers_ws(numpy.ndarray): markers outputed by marker-based watershed algorithm. Boundary is set to -1
#
#     '''
#     sureFront = cv.bitwise_or(sureFront1, sureFront2) #merging sureFront1 and sureFront2
#     unsure = cv.subtract(sureBack, sureFront)
#
#     # Marker labelling
#     _, markers = cv.connectedComponents(sureFront) # Labels background of the image with 0, and other objects are labelled with natural numbers
#     markers += 1 # Give different label to the sure background
#     markers[unsure==255] = 0 # Make sure the unsure ground is labelled 0, can be detected with watershed
#
#     # Watershed
#     mask = cv.imread(os.path.join(mask_path, filename_mask)) # read the original mask (not grayscaled)
#     markers_ws = cv.watershed(mask, markers) # takes in the image and the markers, where the unknown region is labelled as 0
#
#
#     ##################
#     ## Segmentation ##
#     ##################
#     '''
#         Variables:
#             markers_ws(numpy.ndarray): markers outputed by marker-based watershed algorithm.
#             unsure(numpy.ndarray): unsure regions to differentiate foreground and background.
#             markers(numpy.ndarray): markers specifying the regions to flood for watershed.
#
#     '''
#     markers_ws = markers_ws.astype(np.uint8)
#     _, thresh = cv.threshold(markers_ws, 0, 255, cv.THRESH_BINARY|cv.THRESH_OTSU) # Detect edges that includes the newly segmented lines
#     contours, _ = cv.findContours(thresh, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE) # Find the detected edges
#
#     # etching the segmentation onto the mask, converting the image into grayscale
#     cv.cvtColor(cv.drawContours(mask, contours, -1, (0, 0, 0), 5), cv.COLOR_RGB2GRAY)
#
#
#     ############################
#     ## Saving Segmented Masks ##
#     ############################
#     '''
#         mask_name(String): the name of a segmented mask
#                            the format of the naming is (S stands for segmented):
#                                                         SMask_Sample_category-number.jpg
#     '''
#     mask_name = "S" + filename_mask
#     cv.imwrite(os.path.join(segmented_mask_path, mask_name), mask)
# Out:
# Now Segmenting: Mask_Sample_1-13.jpg
# Now Segmenting: Mask_Sample_1-14.jpg
# Now Segmenting: Mask_Sample_1-15.jpg
# Now Segmenting: Mask_Sample_1-16.jpg
# Now Segmenting: Mask_Sample_1-17.jpg
# Now Segmenting: Mask_Sample_1-18.jpg
# Now Segmenting: Mask_Sample_2-13.jpg
# Now Segmenting: Mask_Sample_2-14.jpg
# Now Segmenting: Mask_Sample_2-15.jpg
# Now Segmenting: Mask_Sample_2-16.jpg
# Now Segmenting: Mask_Sample_2-17.jpg
# Now Segmenting: Mask_Sample_2-18.jpg
# Now Segmenting: Mask_Sample_4-13.jpg
# Now Segmenting: Mask_Sample_4-14.jpg
# Now Segmenting: Mask_Sample_4-15.jpg
# Now Segmenting: Mask_Sample_4-16.jpg
# Now Segmenting: Mask_Sample_4-17.jpg
# Now Segmenting: Mask_Sample_4-18.jpg
# Now Segmenting: Mask_Sample_5-13.jpg
# Now Segmenting: Mask_Sample_5-14.jpg
# Now Segmenting: Mask_Sample_5-15.jpg
# Now Segmenting: Mask_Sample_5-16.jpg
# Now Segmenting: Mask_Sample_5-17.jpg
# Now Segmenting: Mask_Sample_5-18.jpg
# Now Segmenting: Mask_Sample_6-13.jpg
# Now Segmenting: Mask_Sample_6-14.jpg
# Now Segmenting: Mask_Sample_6-15.jpg
# Now Segmenting: Mask_Sample_6-16.jpg
# Now Segmenting: Mask_Sample_6-17.jpg
# Now Segmenting: Mask_Sample_6-18.jpg
# Now Segmenting: Mask_Sample_7-13.jpg
# Now Segmenting: Mask_Sample_7-14.jpg
# Now Segmenting: Mask_Sample_7-15.jpg
# Now Segmenting: Mask_Sample_7-16.jpg
# Now Segmenting: Mask_Sample_7-17.jpg
# Now Segmenting: Mask_Sample_7-18.jpg
# Now Segmenting: Mask_Sample_8-13.jpg
# Now Segmenting: Mask_Sample_8-14.jpg
# Now Segmenting: Mask_Sample_8-15.jpg
# Now Segmenting: Mask_Sample_8-16.jpg
# Now Segmenting: Mask_Sample_8-17.jpg
# Now Segmenting: Mask_Sample_8-18.jpg
# Now Segmenting: Mask_Sample_9-13.jpg
# Now Segmenting: Mask_Sample_9-14.jpg
# Now Segmenting: Mask_Sample_9-15.jpg
# Now Segmenting: Mask_Sample_9-16.jpg
# Now Segmenting: Mask_Sample_9-17.jpg
# Now Segmenting: Mask_Sample_9-18.jpg
# Now Segmenting: Mask_Sample_10-13.jpg
# Now Segmenting: Mask_Sample_10-14.jpg
# Now Segmenting: Mask_Sample_10-15.jpg
# Now Segmenting: Mask_Sample_10-16.jpg
# Now Segmenting: Mask_Sample_10-17.jpg
# Now Segmenting: Mask_Sample_10-18.jpg
# Now Segmenting: Mask_Sample_11-13.jpg
# Now Segmenting: Mask_Sample_11-14.jpg
# Now Segmenting: Mask_Sample_11-15.jpg
# Now Segmenting: Mask_Sample_11-16.jpg
# Now Segmenting: Mask_Sample_11-17.jpg
# Now Segmenting: Mask_Sample_11-18.jpg
# Now Segmenting: Mask_Sample_12-13.jpg
# Now Segmenting: Mask_Sample_12-14.jpg
# Now Segmenting: Mask_Sample_12-15.jpg
# Now Segmenting: Mask_Sample_12-16.jpg
# Now Segmenting: Mask_Sample_12-17.jpg
# Now Segmenting: Mask_Sample_12-18.jpg
# Now Segmenting: Mask_Sample_13-7.jpg
# Now Segmenting: Mask_Sample_13-8.jpg
# Now Segmenting: Mask_Sample_13-9.jpg
# Now Segmenting: Mask_Sample_14-13.jpg
# Now Segmenting: Mask_Sample_14-14.jpg
# Now Segmenting: Mask_Sample_14-15.jpg
# Now Segmenting: Mask_Sample_14-16.jpg
# Now Segmenting: Mask_Sample_14-17.jpg
# Now Segmenting: Mask_Sample_14-18.jpg
# Now Segmenting: Mask_Sample_15-10.jpg
# Now Segmenting: Mask_Sample_15-11.jpg
# Now Segmenting: Mask_Sample_15-12.jpg
# Now Segmenting: Mask_Sample_15-13.jpg
# Now Segmenting: Mask_Sample_15-14.jpg
# Now Segmenting: Mask_Sample_15-15.jpg
# Now Segmenting: Mask_Sample_15-16.jpg
# Now Segmenting: Mask_Sample_15-17.jpg
# Now Segmenting: Mask_Sample_15-18.jpg
# Now Segmenting: Mask_Sample_16-8.jpg
# Now Segmenting: Mask_Sample_16-9.jpg
# Now Segmenting: Mask_Sample_16-10.jpg
# Now Segmenting: Mask_Sample_16-11.jpg
# Now Segmenting: Mask_Sample_16-12.jpg
# Now Segmenting: Mask_Sample_16-13.jpg
# Now Segmenting: Mask_Sample_16-14.jpg
# Now Segmenting: Mask_Sample_16-15.jpg
# Now Segmenting: Mask_Sample_16-16.jpg
# Now Segmenting: Mask_Sample_17-1.jpg
# Now Segmenting: Mask_Sample_17-2.jpg
# Now Segmenting: Mask_Sample_17-3.jpg
# Now Segmenting: Mask_Sample_17-4.jpg
# Now Segmenting: Mask_Sample_17-5.jpg
# Now Segmenting: Mask_Sample_17-6.jpg
# Now Segmenting: Mask_Sample_17-7.jpg
# Now Segmenting: Mask_Sample_17-8.jpg
# Now Segmenting: Mask_Sample_17-9.jpg
# Now Segmenting: Mask_Sample_17-10.jpg
# Now Segmenting: Mask_Sample_17-11.jpg
# Now Segmenting: Mask_Sample_17-12.jpg
# Now Segmenting: Mask_Sample_17-13.jpg
# Now Segmenting: Mask_Sample_17-14.jpg
# Now Segmenting: Mask_Sample_17-15.jpg
# Now Segmenting: Mask_Sample_17-16.jpg
# Now Segmenting: Mask_Sample_17-17.jpg
# Now Segmenting: Mask_Sample_17-18.jpg
# Now Segmenting: Mask_Sample_17-19.jpg
# Now Segmenting: Mask_Sample_17-20.jpg
# Now Segmenting: Mask_Sample_17-21.jpg
# Now Segmenting: Mask_Sample_17-22.jpg
# Now Segmenting: Mask_Sample_17-23.jpg
# Now Segmenting: Mask_Sample_17-24.jpg
# Now Segmenting: Mask_Sample_18-6.jpg
# Now Segmenting: Mask_Sample_18-7.jpg
# Now Segmenting: Mask_Sample_18-8.jpg
# Now Segmenting: Mask_Sample_18-9.jpg
# Now Segmenting: Mask_Sample_18-10.jpg
# Now Segmenting: Mask_Sample_18-11.jpg
# Now Segmenting: Mask_Sample_18-12.jpg
# Now Segmenting: Mask_Sample_18-13.jpg
# Now Segmenting: Mask_Sample_18-14.jpg
# Now Segmenting: Mask_Sample_18-15.jpg
# Now Segmenting: Mask_Sample_18-16.jpg
# Now Segmenting: Mask_Sample_18-17.jpg
# Now Segmenting: Mask_Sample_18-18.jpg
# Now Segmenting: Mask_Sample_18-19.jpg
# Now Segmenting: Mask_Sample_18-20.jpg
# Now Segmenting: Mask_Sample_18-21.jpg
# Now Segmenting: Mask_Sample_18-22.jpg
# Now Segmenting: Mask_Sample_18-23.jpg
# Now Segmenting: Mask_Sample_18-24.jpg
# Now Segmenting: Mask_Sample_19-1.jpg
# Now Segmenting: Mask_Sample_19-2.jpg
# Now Segmenting: Mask_Sample_19-3.jpg
# Now Segmenting: Mask_Sample_19-4.jpg
# Now Segmenting: Mask_Sample_19-5.jpg
# Now Segmenting: Mask_Sample_19-6.jpg
# Now Segmenting: Mask_Sample_19-7.jpg
# Now Segmenting: Mask_Sample_19-8.jpg
# Now Segmenting: Mask_Sample_19-9.jpg
# Now Segmenting: Mask_Sample_19-10.jpg
# Now Segmenting: Mask_Sample_19-11.jpg
# Now Segmenting: Mask_Sample_19-12.jpg
# Now Segmenting: Mask_Sample_19-13.jpg
# Now Segmenting: Mask_Sample_19-14.jpg
# Now Segmenting: Mask_Sample_19-15.jpg
# Now Segmenting: Mask_Sample_19-16.jpg
# Now Segmenting: Mask_Sample_19-17.jpg
# Now Segmenting: Mask_Sample_19-18.jpg
# Now Segmenting: Mask_Sample_19-19.jpg
# Now Segmenting: Mask_Sample_19-20.jpg
# Now Segmenting: Mask_Sample_19-21.jpg
# Now Segmenting: Mask_Sample_19-22.jpg
# Now Segmenting: Mask_Sample_19-23.jpg
# Now Segmenting: Mask_Sample_19-24.jpg
# Now Segmenting: Mask_Sample_20-1.jpg
# Now Segmenting: Mask_Sample_20-2.jpg
# Now Segmenting: Mask_Sample_20-3.jpg
# Now Segmenting: Mask_Sample_20-4.jpg
# Now Segmenting: Mask_Sample_20-5.jpg
# Now Segmenting: Mask_Sample_20-6.jpg
# Now Segmenting: Mask_Sample_20-7.jpg
# Now Segmenting: Mask_Sample_20-8.jpg
# Now Segmenting: Mask_Sample_20-9.jpg
# Now Segmenting: Mask_Sample_20-10.jpg
# Now Segmenting: Mask_Sample_20-11.jpg
# Now Segmenting: Mask_Sample_20-12.jpg
# Now Segmenting: Mask_Sample_20-13.jpg
# Now Segmenting: Mask_Sample_20-14.jpg
# Now Segmenting: Mask_Sample_20-15.jpg
# Now Segmenting: Mask_Sample_20-16.jpg
# Now Segmenting: Mask_Sample_20-17.jpg
# Now Segmenting: Mask_Sample_20-18.jpg
# Now Segmenting: Mask_Sample_20-19.jpg
# Now Segmenting: Mask_Sample_20-20.jpg
# Now Segmenting: Mask_Sample_20-21.jpg
# Now Segmenting: Mask_Sample_20-22.jpg
# Now Segmenting: Mask_Sample_20-23.jpg
# Now Segmenting: Mask_Sample_20-24.jpg
# Now Segmenting: Mask_Sample_21-1.jpg
# Now Segmenting: Mask_Sample_21-2.jpg
# Now Segmenting: Mask_Sample_21-3.jpg
# Now Segmenting: Mask_Sample_21-4.jpg
# Now Segmenting: Mask_Sample_21-5.jpg
# Now Segmenting: Mask_Sample_21-6.jpg
# Now Segmenting: Mask_Sample_21-7.jpg
# Now Segmenting: Mask_Sample_21-8.jpg
# Now Segmenting: Mask_Sample_21-9.jpg
# Now Segmenting: Mask_Sample_21-10.jpg
# Now Segmenting: Mask_Sample_21-11.jpg
# Now Segmenting: Mask_Sample_21-12.jpg
# Now Segmenting: Mask_Sample_21-13.jpg
# Now Segmenting: Mask_Sample_21-14.jpg
# Now Segmenting: Mask_Sample_21-15.jpg
# Now Segmenting: Mask_Sample_21-16.jpg
# Now Segmenting: Mask_Sample_21-17.jpg
# Now Segmenting: Mask_Sample_21-18.jpg
# Now Segmenting: Mask_Sample_21-19.jpg
# Now Segmenting: Mask_Sample_21-20.jpg
# Now Segmenting: Mask_Sample_21-21.jpg
# Now Segmenting: Mask_Sample_21-22.jpg
# Now Segmenting: Mask_Sample_21-23.jpg
# Now Segmenting: Mask_Sample_21-24.jpg
# Now Segmenting: Mask_Sample_22-1.jpg
# Now Segmenting: Mask_Sample_22-2.jpg
# Now Segmenting: Mask_Sample_22-3.jpg
# Now Segmenting: Mask_Sample_22-4.jpg
# Now Segmenting: Mask_Sample_22-5.jpg
# Now Segmenting: Mask_Sample_22-6.jpg
# Now Segmenting: Mask_Sample_22-7.jpg
# Now Segmenting: Mask_Sample_22-8.jpg
# Now Segmenting: Mask_Sample_22-9.jpg
# Now Segmenting: Mask_Sample_22-10.jpg
# Now Segmenting: Mask_Sample_22-11.jpg
# Now Segmenting: Mask_Sample_22-12.jpg
# Now Segmenting: Mask_Sample_22-13.jpg
# Now Segmenting: Mask_Sample_22-14.jpg
# Now Segmenting: Mask_Sample_22-15.jpg
# Now Segmenting: Mask_Sample_22-16.jpg
# Now Segmenting: Mask_Sample_22-17.jpg
# Now Segmenting: Mask_Sample_22-18.jpg
# Now Segmenting: Mask_Sample_22-19.jpg
# Now Segmenting: Mask_Sample_22-20.jpg
# Now Segmenting: Mask_Sample_22-21.jpg
# Now Segmenting: Mask_Sample_22-22.jpg
# Now Segmenting: Mask_Sample_22-23.jpg
# Now Segmenting: Mask_Sample_22-24.jpg
# Now Segmenting: Mask_Sample_23-1.jpg
# Now Segmenting: Mask_Sample_23-2.jpg
# Now Segmenting: Mask_Sample_23-3.jpg
# Now Segmenting: Mask_Sample_23-4.jpg
# Now Segmenting: Mask_Sample_23-5.jpg
# Now Segmenting: Mask_Sample_23-6.jpg
# Now Segmenting: Mask_Sample_23-7.jpg
# Now Segmenting: Mask_Sample_23-8.jpg
# Now Segmenting: Mask_Sample_23-9.jpg
# Now Segmenting: Mask_Sample_23-10.jpg
# Now Segmenting: Mask_Sample_23-11.jpg
# Now Segmenting: Mask_Sample_23-12.jpg
# Now Segmenting: Mask_Sample_23-13.jpg
# Now Segmenting: Mask_Sample_23-14.jpg
# Now Segmenting: Mask_Sample_23-15.jpg
# Now Segmenting: Mask_Sample_23-16.jpg
# Now Segmenting: Mask_Sample_23-17.jpg
# Now Segmenting: Mask_Sample_23-18.jpg
# Now Segmenting: Mask_Sample_23-19.jpg
# Now Segmenting: Mask_Sample_23-20.jpg
# Now Segmenting: Mask_Sample_23-21.jpg
# Now Segmenting: Mask_Sample_23-22.jpg
# Now Segmenting: Mask_Sample_23-23.jpg
# Now Segmenting: Mask_Sample_23-24.jpg
# Now Segmenting: Mask_Sample_24-1.jpg
# Now Segmenting: Mask_Sample_24-2.jpg
# Now Segmenting: Mask_Sample_24-3.jpg
# Now Segmenting: Mask_Sample_24-4.jpg
# Now Segmenting: Mask_Sample_24-5.jpg
# Now Segmenting: Mask_Sample_24-6.jpg
# Now Segmenting: Mask_Sample_25-1.jpg
# Now Segmenting: Mask_Sample_25-2.jpg
# Now Segmenting: Mask_Sample_25-3.jpg
# Now Segmenting: Mask_Sample_25-4.jpg
# Now Segmenting: Mask_Sample_25-5.jpg
# Now Segmenting: Mask_Sample_25-6.jpg
# Now Segmenting: Mask_Sample_25-7.jpg
# Now Segmenting: Mask_Sample_25-8.jpg
# Now Segmenting: Mask_Sample_25-9.jpg
# Now Segmenting: Mask_Sample_25-10.jpg
# Now Segmenting: Mask_Sample_25-11.jpg
# Now Segmenting: Mask_Sample_25-12.jpg
# Now Segmenting: Mask_Sample_25-13.jpg
# Now Segmenting: Mask_Sample_25-14.jpg
# Now Segmenting: Mask_Sample_25-15.jpg
# Now Segmenting: Mask_Sample_25-16.jpg
# Now Segmenting: Mask_Sample_25-17.jpg
# Now Segmenting: Mask_Sample_25-18.jpg
# Now Segmenting: Mask_Sample_25-19.jpg
# Now Segmenting: Mask_Sample_25-20.jpg
# Now Segmenting: Mask_Sample_25-21.jpg
# Now Segmenting: Mask_Sample_25-22.jpg
# Now Segmenting: Mask_Sample_25-23.jpg
# Now Segmenting: Mask_Sample_25-24.jpg
# Now Segmenting: Mask_Sample_26-8.jpg
# Now Segmenting: Mask_Sample_26-9.jpg
# Now Segmenting: Mask_Sample_26-10.jpg
# Now Segmenting: Mask_Sample_26-11.jpg
# Now Segmenting: Mask_Sample_26-12.jpg
# Now Segmenting: Mask_Sample_26-13.jpg
# Now Segmenting: Mask_Sample_26-14.jpg
# Now Segmenting: Mask_Sample_26-15.jpg
# Now Segmenting: Mask_Sample_26-16.jpg
# Now Segmenting: Mask_Sample_26-17.jpg
# Now Segmenting: Mask_Sample_26-18.jpg
# Now Segmenting: Mask_Sample_26-19.jpg
# Now Segmenting: Mask_Sample_26-20.jpg
# Now Segmenting: Mask_Sample_26-21.jpg
# Now Segmenting: Mask_Sample_26-22.jpg
# Now Segmenting: Mask_Sample_26-23.jpg
# Now Segmenting: Mask_Sample_26-24.jpg
# Now Segmenting: Mask_Sample_27-1.jpg
# Now Segmenting: Mask_Sample_27-2.jpg
# Now Segmenting: Mask_Sample_27-3.jpg
# Now Segmenting: Mask_Sample_27-4.jpg
# Now Segmenting: Mask_Sample_27-5.jpg
# Now Segmenting: Mask_Sample_27-6.jpg
# Now Segmenting: Mask_Sample_27-7.jpg
# Now Segmenting: Mask_Sample_27-8.jpg
# Now Segmenting: Mask_Sample_27-9.jpg
# Now Segmenting: Mask_Sample_27-10.jpg
# Now Segmenting: Mask_Sample_27-11.jpg
# Now Segmenting: Mask_Sample_27-12.jpg
# Now Segmenting: Mask_Sample_27-13.jpg
# Now Segmenting: Mask_Sample_27-14.jpg
# Now Segmenting: Mask_Sample_27-15.jpg
# Now Segmenting: Mask_Sample_27-16.jpg
# Now Segmenting: Mask_Sample_27-17.jpg
# Now Segmenting: Mask_Sample_27-18.jpg
# Now Segmenting: Mask_Sample_27-19.jpg
# Now Segmenting: Mask_Sample_27-20.jpg
# Now Segmenting: Mask_Sample_27-21.jpg
# Now Segmenting: Mask_Sample_27-22.jpg
# Now Segmenting: Mask_Sample_27-23.jpg
# Now Segmenting: Mask_Sample_27-24.jpg
# Now Segmenting: Mask_Sample_28-1.jpg
# Now Segmenting: Mask_Sample_28-2.jpg
# Now Segmenting: Mask_Sample_28-3.jpg
# Now Segmenting: Mask_Sample_28-4.jpg
# Now Segmenting: Mask_Sample_28-5.jpg
# Now Segmenting: Mask_Sample_28-6.jpg
# Now Segmenting: Mask_Sample_28-7.jpg
# Now Segmenting: Mask_Sample_28-8.jpg
# Now Segmenting: Mask_Sample_28-9.jpg
# Now Segmenting: Mask_Sample_28-10.jpg
# Now Segmenting: Mask_Sample_28-11.jpg
# Now Segmenting: Mask_Sample_28-12.jpg
# Now Segmenting: Mask_Sample_28-13.jpg
# Now Segmenting: Mask_Sample_28-14.jpg
# Now Segmenting: Mask_Sample_28-15.jpg
# Now Segmenting: Mask_Sample_28-16.jpg
# Now Segmenting: Mask_Sample_28-17.jpg
# Now Segmenting: Mask_Sample_28-18.jpg
# Now Segmenting: Mask_Sample_28-19.jpg
# Now Segmenting: Mask_Sample_28-20.jpg
# Now Segmenting: Mask_Sample_28-21.jpg
# Now Segmenting: Mask_Sample_28-22.jpg
# Now Segmenting: Mask_Sample_28-23.jpg
# Now Segmenting: Mask_Sample_28-24.jpg
# Now Segmenting: Mask_Sample_29-1.jpg
# Now Segmenting: Mask_Sample_29-2.jpg
# Now Segmenting: Mask_Sample_29-3.jpg
# Now Segmenting: Mask_Sample_29-4.jpg
# Now Segmenting: Mask_Sample_29-5.jpg
# Now Segmenting: Mask_Sample_29-6.jpg
# Now Segmenting: Mask_Sample_29-7.jpg
# Now Segmenting: Mask_Sample_29-8.jpg
# Now Segmenting: Mask_Sample_29-9.jpg
# Now Segmenting: Mask_Sample_29-10.jpg
# Now Segmenting: Mask_Sample_29-11.jpg
# Now Segmenting: Mask_Sample_29-12.jpg
# Now Segmenting: Mask_Sample_29-13.jpg
# Now Segmenting: Mask_Sample_29-14.jpg
# Now Segmenting: Mask_Sample_29-15.jpg
# Now Segmenting: Mask_Sample_29-16.jpg
# Now Segmenting: Mask_Sample_29-17.jpg
# Now Segmenting: Mask_Sample_29-18.jpg
# Now Segmenting: Mask_Sample_29-19.jpg
# Now Segmenting: Mask_Sample_29-20.jpg
# Now Segmenting: Mask_Sample_29-21.jpg
# Now Segmenting: Mask_Sample_29-22.jpg
# Now Segmenting: Mask_Sample_29-23.jpg
# Now Segmenting: Mask_Sample_29-24.jpg
# Now Segmenting: Mask_Sample_30-1.jpg
# Now Segmenting: Mask_Sample_30-2.jpg
# Now Segmenting: Mask_Sample_30-3.jpg
# Now Segmenting: Mask_Sample_30-4.jpg
# Now Segmenting: Mask_Sample_30-5.jpg
# Now Segmenting: Mask_Sample_30-6.jpg
# Now Segmenting: Mask_Sample_30-7.jpg
# Now Segmenting: Mask_Sample_30-8.jpg
# Now Segmenting: Mask_Sample_30-9.jpg
# Now Segmenting: Mask_Sample_30-10.jpg
# Now Segmenting: Mask_Sample_30-11.jpg
# Now Segmenting: Mask_Sample_30-12.jpg
# Now Segmenting: Mask_Sample_30-13.jpg
# Now Segmenting: Mask_Sample_30-14.jpg
# Now Segmenting: Mask_Sample_30-15.jpg
# Now Segmenting: Mask_Sample_30-16.jpg
# Now Segmenting: Mask_Sample_30-17.jpg
# Now Segmenting: Mask_Sample_30-18.jpg
# Now Segmenting: Mask_Sample_30-19.jpg
# Now Segmenting: Mask_Sample_30-20.jpg
# Now Segmenting: Mask_Sample_30-21.jpg
# Now Segmenting: Mask_Sample_30-22.jpg
# Now Segmenting: Mask_Sample_30-23.jpg
# Now Segmenting: Mask_Sample_30-24.jpg
# Now Segmenting: Mask_Sample_31-8.jpg
# Now Segmenting: Mask_Sample_31-9.jpg
# Now Segmenting: Mask_Sample_31-10.jpg
# Now Segmenting: Mask_Sample_31-11.jpg
# Now Segmenting: Mask_Sample_31-12.jpg
# Now Segmenting: Mask_Sample_31-13.jpg
# Now Segmenting: Mask_Sample_31-14.jpg
# Now Segmenting: Mask_Sample_31-15.jpg
# Now Segmenting: Mask_Sample_31-16.jpg
# Now Segmenting: Mask_Sample_31-17.jpg
# Now Segmenting: Mask_Sample_31-18.jpg
# Now Segmenting: Mask_Sample_31-19.jpg
# Now Segmenting: Mask_Sample_31-20.jpg
# Now Segmenting: Mask_Sample_31-21.jpg
# Now Segmenting: Mask_Sample_31-22.jpg
# Now Segmenting: Mask_Sample_31-23.jpg
# Now Segmenting: Mask_Sample_31-24.jpg
# Now Segmenting: Mask_Sample_32-1.jpg
# Now Segmenting: Mask_Sample_32-2.jpg
# Now Segmenting: Mask_Sample_32-3.jpg
# Now Segmenting: Mask_Sample_32-4.jpg
# Now Segmenting: Mask_Sample_32-5.jpg
# Now Segmenting: Mask_Sample_32-6.jpg
# Now Segmenting: Mask_Sample_32-7.jpg
# Now Segmenting: Mask_Sample_32-8.jpg
# Now Segmenting: Mask_Sample_32-9.jpg
# Now Segmenting: Mask_Sample_32-10.jpg
# Now Segmenting: Mask_Sample_32-11.jpg
# Now Segmenting: Mask_Sample_32-12.jpg
# Now Segmenting: Mask_Sample_32-13.jpg
# Now Segmenting: Mask_Sample_32-14.jpg
# Now Segmenting: Mask_Sample_32-15.jpg
# Now Segmenting: Mask_Sample_32-16.jpg
# Now Segmenting: Mask_Sample_32-17.jpg
# Now Segmenting: Mask_Sample_32-18.jpg
# Now Segmenting: Mask_Sample_32-19.jpg
# Now Segmenting: Mask_Sample_32-20.jpg
# Now Segmenting: Mask_Sample_32-21.jpg
# Now Segmenting: Mask_Sample_32-22.jpg
# Now Segmenting: Mask_Sample_32-23.jpg
# Now Segmenting: Mask_Sample_32-24.jpg
# Now Segmenting: Mask_Sample_33-13.jpg
# Now Segmenting: Mask_Sample_33-14.jpg
# Now Segmenting: Mask_Sample_33-15.jpg
# Now Segmenting: Mask_Sample_33-16.jpg
# Now Segmenting: Mask_Sample_33-17.jpg
# Now Segmenting: Mask_Sample_33-18.jpg
# Now Segmenting: Mask_Sample_33-19.jpg
# Now Segmenting: Mask_Sample_33-20.jpg
# Now Segmenting: Mask_Sample_33-21.jpg
# Now Segmenting: Mask_Sample_33-22.jpg
# Now Segmenting: Mask_Sample_33-23.jpg
# Now Segmenting: Mask_Sample_33-24.jpg
# Now Segmenting: Mask_Sample_34-7.jpg
# Now Segmenting: Mask_Sample_34-8.jpg
# Now Segmenting: Mask_Sample_34-9.jpg
# Now Segmenting: Mask_Sample_34-10.jpg
# Now Segmenting: Mask_Sample_34-11.jpg
# Now Segmenting: Mask_Sample_34-12.jpg
# Now Segmenting: Mask_Sample_34-13.jpg
# Now Segmenting: Mask_Sample_34-14.jpg
# Now Segmenting: Mask_Sample_34-15.jpg
# Now Segmenting: Mask_Sample_34-16.jpg
# Now Segmenting: Mask_Sample_34-17.jpg
# Now Segmenting: Mask_Sample_34-18.jpg
# Now Segmenting: Mask_Sample_34-19.jpg
# Now Segmenting: Mask_Sample_34-20.jpg
# Now Segmenting: Mask_Sample_34-21.jpg
# Now Segmenting: Mask_Sample_34-22.jpg
# Now Segmenting: Mask_Sample_34-23.jpg
# Now Segmenting: Mask_Sample_34-24.jpg
# Now Segmenting: Mask_Sample_35-1.jpg
# Now Segmenting: Mask_Sample_35-2.jpg
# Now Segmenting: Mask_Sample_35-3.jpg
# Now Segmenting: Mask_Sample_35-4.jpg
# Now Segmenting: Mask_Sample_35-5.jpg
# Now Segmenting: Mask_Sample_35-6.jpg
# Now Segmenting: Mask_Sample_35-7.jpg
# Now Segmenting: Mask_Sample_35-8.jpg
# Now Segmenting: Mask_Sample_35-9.jpg
# Now Segmenting: Mask_Sample_35-10.jpg
# Now Segmenting: Mask_Sample_35-11.jpg
# Now Segmenting: Mask_Sample_35-12.jpg
# Now Segmenting: Mask_Sample_35-13.jpg
# Now Segmenting: Mask_Sample_35-14.jpg
# Now Segmenting: Mask_Sample_35-15.jpg
# Now Segmenting: Mask_Sample_35-16.jpg
# Now Segmenting: Mask_Sample_35-17.jpg
# Now Segmenting: Mask_Sample_35-18.jpg
# Now Segmenting: Mask_Sample_35-19.jpg
# Now Segmenting: Mask_Sample_35-20.jpg
# Now Segmenting: Mask_Sample_35-21.jpg
# Now Segmenting: Mask_Sample_35-22.jpg
# Now Segmenting: Mask_Sample_35-23.jpg
# Now Segmenting: Mask_Sample_35-24.jpg
# Now Segmenting: Mask_Sample_36-13.jpg
# Now Segmenting: Mask_Sample_36-14.jpg
# Now Segmenting: Mask_Sample_36-15.jpg
# Now Segmenting: Mask_Sample_36-16.jpg
# Now Segmenting: Mask_Sample_36-17.jpg
# Now Segmenting: Mask_Sample_36-18.jpg
# Now Segmenting: Mask_Sample_36-19.jpg
# Now Segmenting: Mask_Sample_36-20.jpg
# Now Segmenting: Mask_Sample_36-21.jpg
# Now Segmenting: Mask_Sample_36-22.jpg
# Now Segmenting: Mask_Sample_36-23.jpg
# Now Segmenting: Mask_Sample_36-24.jpg
# Now Segmenting: Mask_Sample_37-13.jpg
# Now Segmenting: Mask_Sample_37-14.jpg
# Now Segmenting: Mask_Sample_37-15.jpg
# Now Segmenting: Mask_Sample_37-16.jpg
# Now Segmenting: Mask_Sample_37-17.jpg
# Now Segmenting: Mask_Sample_37-18.jpg
# Now Segmenting: Mask_Sample_37-19.jpg
# Now Segmenting: Mask_Sample_37-20.jpg
# Now Segmenting: Mask_Sample_37-21.jpg
# Now Segmenting: Mask_Sample_37-22.jpg
# Now Segmenting: Mask_Sample_37-23.jpg
# Now Segmenting: Mask_Sample_37-24.jpg
# Now Segmenting: Mask_Sample_38-7.jpg
# Now Segmenting: Mask_Sample_38-8.jpg
# Now Segmenting: Mask_Sample_38-9.jpg
# Now Segmenting: Mask_Sample_38-10.jpg
# Now Segmenting: Mask_Sample_38-11.jpg
# Now Segmenting: Mask_Sample_38-12.jpg
# Now Segmenting: Mask_Sample_38-13.jpg
# Now Segmenting: Mask_Sample_38-14.jpg
# Now Segmenting: Mask_Sample_38-15.jpg
# Now Segmenting: Mask_Sample_38-16.jpg
# Now Segmenting: Mask_Sample_38-17.jpg
# Now Segmenting: Mask_Sample_38-18.jpg
# Now Segmenting: Mask_Sample_38-19.jpg
# Now Segmenting: Mask_Sample_38-20.jpg
# Now Segmenting: Mask_Sample_38-21.jpg
# Now Segmenting: Mask_Sample_38-22.jpg
# Now Segmenting: Mask_Sample_38-23.jpg
# Now Segmenting: Mask_Sample_38-24.jpg

# %% [markdown]
# #### Part II - Colony Counting
# Colonies are counted from the segmented mask with moments.\
# \
# Main techniques used:
# 1. connectedComponent: separating small colonies from large colonies
# 1. ConvexHull: segment colonies by convex hull

# %%
ground_truth = [[113, 90, 99, 87, 96, 93, 92, 95, 96, 76, 60, 63, 10, 11, 10, 1, 1, 1],
                [145, 175, 160, 167, 156, 120, 395, 446, 436, 107, 101, 92, 43, 28, 45, 4, 3, 6],
                [103, 112, 72, 74, 76, 100, 62, 74, 79, 71, 83, 79, 8, 11, 10, 3, 2, 12],
                [170, 176, 160, 139, 137, 156, 101, 98, 93, 96, 102, 87, 27, 29, 20, 7, 4, 4],
                [165, 159, 129, 149, 164, 160, 90, 89, 103, 116, 127, 128, 18, 18, 16, 3, 8, 9],
                [139, 140, 123, 117, 106, 121, 89, 100, 79, 91, 100, 102, 14, 22, 9, 7, 10, 7],
                [160, 153, 144, 140, 140, 151, 149, 143, 146, 166, 168, 169, 25, 20, 20, 14, 11, 9],
                [157, 160, 117, 138, 140, 155, 144, 118, 117, 138, 125, 108, 27, 29, 25, 6, 11, 10],
                [169, 156, 173, 217, 171, 170, 123, 125, 109, 166, 143, 173, 32, 19, 21, 8, 6, 4],
                [153, 156, 135, 157, 138, 163, 94, 92, 72, 119, 117, 92, 31, 31, 21, 4, 9, 8],
                [147, 158, 143, 156, 149, 119, 118, 143, 121, 168, 175, 144, 28, 27, 18, 10, 8, 13],
                [137, 115, 115, 126, 122, 136, 93, 105, 114, 137, 119, 142, 28, 29, 25, 8, 12, 7],
                [228, 240, 294, 259, 243, 239, 1, 1, 0],
                [114, 98, 115, 104, 98, 121, 99, 75, 75, 59, 76, 62, 9, 9, 14, 4, 1, 0],
                [220, 202, 213, 176, 209, 201, 112, 127, 101, 65, 62, 64, 18, 23, 31, 5, 3, 5],
                [145, 152, 167, 164, 167, 166, 114, 82, 74, 59, 12, 10, 13, 1, 3, 4],
                [61, 59, 62, 60, 67, 57, 30, 19, 36, 33, 45, 32, 6, 7, 16, 16, 16, 7, 15, 15, 17, 33, 28, 28],
                [103, 95, 87, 87, 83, 90, 44, 48, 51, 45, 63, 55, 13, 19, 17, 19, 20, 21, 6, 7, 2, 4, 2, 4],
                [74, 72, 93, 65, 76, 87, 60, 55, 49, 59, 49, 66, 16, 11, 9, 15, 12, 14, 4, 2, 5, 7, 4, 8],
                [8, 11, 13, 6, 10, 5, 46, 55, 53, 69, 67, 52, 8, 11, 14, 6, 19, 12, 12, 18, 11, 14, 15, 11],
                [70, 90, 80, 96, 93, 76, 68, 63, 65, 78, 75, 59, 10, 6, 10, 8, 16, 9, 3, 2, 4, 6, 5, 4],
                [43, 48, 46, 34, 41, 41, 12, 16, 8, 25, 24, 20, 3, 7, 12, 6, 7, 5, 4, 2, 2, 1, 2, 0],
                [133, 130, 99, 105, 117, 110, 34, 49, 55, 48, 55, 65, 17, 22, 14, 14, 16, 13, 2, 2, 3, 8, 1, 6],
                [29, 40, 5, 12, 9, 6],
                [118, 102, 108, 101, 112, 113, 46, 45, 35, 47, 54, 45, 11, 16, 16, 12, 20, 17, 3, 2, 1, 4, 3, 1],
                [144, 117, 147, 149, 125, 122, 56, 73, 52, 40, 55, 51, 21, 29, 30, 23, 19, 32, 9, 5, 3, 8, 3, 5],
                [131, 148, 160, 155, 158, 132, 96, 110, 79, 116, 123, 108, 46, 33, 46, 40, 45, 42, 42, 26, 40, 42, 30, 36], #27
                [157, 144, 143, 142, 159, 163, 78, 78, 70, 149, 153, 124, 53, 43, 44, 49, 45, 45, 28, 26, 22, 24, 20, 20],
                [134, 128, 108, 121, 111, 105, 94, 85, 84, 110, 126, 116, 53, 48, 49, 51, 51, 40, 41, 46, 36, 38, 42, 37],
                [159, 134, 163, 165, 179, 147, 94, 95, 92, 158, 149, 158, 41, 39, 39, 38, 45, 47, 36, 30, 32, 34, 36, 25],
                [181, 136, 161, 158, 155, 130, 70, 74, 72, 128, 140, 125, 51, 42, 46, 52, 57, 48, 18, 25, 27, 20, 23, 19],
                [137, 141, 137, 147, 158, 124, 82, 75, 80, 166, 143, 130, 28, 34, 39, 47, 39, 46, 17, 25, 21, 19, 22, 20],
                [146, 146, 164, 125, 150, 160, 111, 110, 98, 134, 120, 129, 64, 46, 52, 60, 43, 55, 36, 34, 42, 31, 28, 36],
                [109, 107, 110, 78, 139, 120, 40, 57, 73, 60, 65, 66, 14, 29, 31, 26, 22, 25, 8, 8, 10, 11, 16, 7],
                [131, 114, 139, 110, 125, 123, 104, 105, 118, 83, 95, 90, 13, 19, 18, 15, 17, 12, 10, 12, 7, 7, 7, 7],
                [114, 164, 154, 141, 129, 118, 112, 122, 119, 160, 184, 175, 30, 36, 34, 17, 33, 33, 19, 17, 8, 8, 17, 18],
                [119, 130, 132, 135, 124, 140, 87, 107, 109, 132, 134, 100, 22, 14, 22, 19, 23, 17, 10, 4, 8, 9, 6, 4],
                [146, 143, 127, 148, 123, 112, 81, 102, 82, 90, 106, 101, 35, 35, 28, 31, 34, 28, 9, 9, 8, 9, 11, 9]]

# %%
# %%skip_if count_colonies == False
#
#
# def accuracy_calc(ground_truth, experimental):
#     '''
#         Calculate the accuracy of the segmented mask from the manually counted colony count.
#
#         Variables:
#             ground_truth(list): a list of manually counted colony count for accuracy calculations.
#             experimental(list): a list of counts from algorithm
#             batch(int): for indexing the batch in ground_truth and experimental lists.
#
#         Return:
#             accuracy(double): average accuracy calculated with the masks in a batch
#
#     '''
#     if ground_truth == 0:
#         percent_diff = 0 # discount the masks with no colonies
#     else:
#         percent_diff = abs((experimental - ground_truth)) / ground_truth
#
#     if(percent_diff>1):
#         percent_diff = 1
#     accuracy = (1 - percent_diff) * 100
#     return accuracy
#
#
# ####################
# ## Count Colonies ##
# ####################
# '''
#     Variables:
#         experimental(list): a list of counts from algorithm
#         total_accuracy(list): a list of accuracies of each batch
#         batch(int): for indexing the batch in ground_truth and experimental lists.
#         sample(int): for indexing a particular sample in a given batch.
#         mask(numpy.ndarray): segmented mask
#         counter(int): for counting the number of colonies in a mask
#
# '''
# experimental = [] # storing all of the experimental counts
# total_accuracy = []
# mask_dir = sorted(os.listdir(segmented_mask_path), key=numericalSort)
#
# for filename in mask_dir:
#     mask_org = cv.imread(os.path.join(segmented_mask_path, filename))
#     mask = cv.cvtColor(mask_org, cv.COLOR_BGR2GRAY).astype(np.uint8)
#
#     ## Find contours of the segmented colonies ##
#     _, thresh = cv.threshold(mask, 15, 255, cv.THRESH_BINARY|cv.THRESH_OTSU)
#     contours, _ = cv.findContours(thresh, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
#     cv.drawContours(mask_org, contours, -1, (0, 255, 0), 5)
#     destination = os.path.join('.', 'Data', 'HCT116_Dataset', 'contour_small', filename)
#     cv.imwrite(destination, mask_org)
#
#
#     ## Count the colonies based on the contours ##
#     counter = 0
#     for contour in contours:
#         # Compute moments of the contour
#         M = cv.moments(contour)
#         if M['m00'] != 0:
#             counter += 1 # Detected a colony
#
#     print(f"{filename} has {counter} colonies")
#
#
#     ## Calculate the accuracy of a batch ##
#     if test_accuracy == True:
#         batch = int(filename[13]) - 1
#         try:
#             sample = int(filename[15:17]) - 1
#         except:
#             sample = int(filename[15:16]) - 1
#         accuracy = accuracy_calc(ground_truth=ground_truth[batch][sample], experimental=counter)
#         print(accuracy)
#         total_accuracy.append(accuracy)
#
#
# ## Calculate accuracy of the entire dataset ##
# if test_accuracy == True:
#     avg_accuracy = sum(total_accuracy) / len(total_accuracy)
#     print(f"The averaged accuracy for the entire dataset is {avg_accuracy}")
# Out:
# SMask_Sample_1-1.jpg has 84 colonies
# 74.33628318584071
# SMask_Sample_1-2.jpg has 76 colonies
# 84.44444444444444
# SMask_Sample_1-3.jpg has 62 colonies
# 62.62626262626263
# SMask_Sample_1-4.jpg has 73 colonies
# 83.9080459770115
# SMask_Sample_1-5.jpg has 77 colonies
# 80.20833333333334
# SMask_Sample_1-6.jpg has 73 colonies
# 78.49462365591397
# SMask_Sample_1-7.jpg has 76 colonies
# 82.6086956521739
# SMask_Sample_1-8.jpg has 81 colonies
# 85.26315789473684
# SMask_Sample_1-9.jpg has 83 colonies
# 86.45833333333334
# SMask_Sample_1-10.jpg has 66 colonies
# 86.8421052631579
# SMask_Sample_1-11.jpg has 53 colonies
# 88.33333333333333
# SMask_Sample_1-12.jpg has 47 colonies
# 74.60317460317461
# SMask_Sample_1-13.jpg has 9 colonies
# 90.0
# SMask_Sample_1-14.jpg has 13 colonies
# 81.81818181818181
# SMask_Sample_1-15.jpg has 11 colonies
# 90.0
# SMask_Sample_1-16.jpg has 1 colonies
# 100.0
# SMask_Sample_1-17.jpg has 1 colonies
# 100.0
# SMask_Sample_1-18.jpg has 1 colonies
# 100.0
# SMask_Sample_2-1.jpg has 100 colonies
# 68.96551724137932
# SMask_Sample_2-2.jpg has 120 colonies
# 68.57142857142857
# SMask_Sample_2-3.jpg has 103 colonies
# 64.375
# SMask_Sample_2-4.jpg has 114 colonies
# 68.26347305389223
# SMask_Sample_2-5.jpg has 99 colonies
# 63.46153846153846
# SMask_Sample_2-6.jpg has 97 colonies
# 80.83333333333333
# SMask_Sample_2-7.jpg has 196 colonies
# 49.62025316455696
# SMask_Sample_2-8.jpg has 224 colonies
# 50.224215246636774
# SMask_Sample_2-9.jpg has 185 colonies
# 42.43119266055045
# SMask_Sample_2-10.jpg has 90 colonies
# 84.11214953271028
# SMask_Sample_2-11.jpg has 102 colonies
# 99.00990099009901
# SMask_Sample_2-12.jpg has 91 colonies
# 98.91304347826086
# SMask_Sample_2-13.jpg has 36 colonies
# 83.72093023255813
# SMask_Sample_2-14.jpg has 29 colonies
# 96.42857142857143
# SMask_Sample_2-15.jpg has 48 colonies
# 93.33333333333333
# SMask_Sample_2-16.jpg has 4 colonies
# 100.0
# SMask_Sample_2-17.jpg has 4 colonies
# 66.66666666666667
# SMask_Sample_2-18.jpg has 7 colonies
# 83.33333333333334
# SMask_Sample_3-1.jpg has 88 colonies
# 85.4368932038835
# SMask_Sample_3-2.jpg has 87 colonies
# 77.67857142857143
# SMask_Sample_3-3.jpg has 57 colonies
# 79.16666666666666
# SMask_Sample_3-4.jpg has 66 colonies
# 89.1891891891892
# SMask_Sample_3-5.jpg has 64 colonies
# 84.21052631578947
# SMask_Sample_3-6.jpg has 82 colonies
# 82.0
# SMask_Sample_3-7.jpg has 58 colonies
# 93.5483870967742
# SMask_Sample_3-8.jpg has 62 colonies
# 83.78378378378379
# SMask_Sample_3-9.jpg has 74 colonies
# 93.67088607594937
# SMask_Sample_3-10.jpg has 68 colonies
# 95.77464788732395
# SMask_Sample_3-11.jpg has 76 colonies
# 91.56626506024097
# SMask_Sample_3-12.jpg has 70 colonies
# 88.60759493670886
# SMask_Sample_3-13.jpg has 9 colonies
# 87.5
# SMask_Sample_3-14.jpg has 11 colonies
# 100.0
# SMask_Sample_3-15.jpg has 13 colonies
# 70.0
# SMask_Sample_3-16.jpg has 6 colonies
# 0.0
# SMask_Sample_3-17.jpg has 4 colonies
# 0.0
# SMask_Sample_3-18.jpg has 12 colonies
# 100.0
# SMask_Sample_4-1.jpg has 126 colonies
# 74.11764705882354
# SMask_Sample_4-2.jpg has 125 colonies
# 71.02272727272727
# SMask_Sample_4-3.jpg has 119 colonies
# 74.375
# SMask_Sample_4-4.jpg has 106 colonies
# 76.2589928057554
# SMask_Sample_4-5.jpg has 107 colonies
# 78.1021897810219
# SMask_Sample_4-6.jpg has 111 colonies
# 71.15384615384616
# SMask_Sample_4-7.jpg has 96 colonies
# 95.04950495049505
# SMask_Sample_4-8.jpg has 87 colonies
# 88.77551020408163
# SMask_Sample_4-9.jpg has 83 colonies
# 89.24731182795699
# SMask_Sample_4-10.jpg has 92 colonies
# 95.83333333333334
# SMask_Sample_4-11.jpg has 98 colonies
# 96.07843137254902
# SMask_Sample_4-12.jpg has 86 colonies
# 98.85057471264368
# SMask_Sample_4-13.jpg has 27 colonies
# 100.0
# SMask_Sample_4-14.jpg has 27 colonies
# 93.10344827586206
# SMask_Sample_4-15.jpg has 23 colonies
# 85.0
# SMask_Sample_4-16.jpg has 10 colonies
# 57.14285714285714
# SMask_Sample_4-17.jpg has 5 colonies
# 75.0
# SMask_Sample_4-18.jpg has 7 colonies
# 25.0
# SMask_Sample_5-1.jpg has 115 colonies
# 69.6969696969697
# SMask_Sample_5-2.jpg has 104 colonies
# 65.40880503144655
# SMask_Sample_5-3.jpg has 85 colonies
# 65.89147286821706
# SMask_Sample_5-4.jpg has 109 colonies
# 73.15436241610738
# SMask_Sample_5-5.jpg has 118 colonies
# 71.95121951219512
# SMask_Sample_5-6.jpg has 110 colonies
# 68.75
# SMask_Sample_5-7.jpg has 86 colonies
# 95.55555555555556
# SMask_Sample_5-8.jpg has 80 colonies
# 89.8876404494382
# SMask_Sample_5-9.jpg has 75 colonies
# 72.81553398058253
# SMask_Sample_5-10.jpg has 85 colonies
# 73.27586206896552
# SMask_Sample_5-11.jpg has 98 colonies
# 77.16535433070865
# SMask_Sample_5-12.jpg has 111 colonies
# 86.71875
# SMask_Sample_5-13.jpg has 19 colonies
# 94.44444444444444
# SMask_Sample_5-14.jpg has 15 colonies
# 83.33333333333334
# SMask_Sample_5-15.jpg has 21 colonies
# 68.75
# SMask_Sample_5-16.jpg has 3 colonies
# 100.0
# SMask_Sample_5-17.jpg has 3 colonies
# 37.5
# SMask_Sample_5-18.jpg has 10 colonies
# 88.88888888888889
# SMask_Sample_6-1.jpg has 114 colonies
# 82.01438848920863
# SMask_Sample_6-2.jpg has 109 colonies
# 77.85714285714286
# SMask_Sample_6-3.jpg has 106 colonies
# 86.1788617886179
# SMask_Sample_6-4.jpg has 92 colonies
# 78.63247863247864
# SMask_Sample_6-5.jpg has 89 colonies
# 83.9622641509434
# SMask_Sample_6-6.jpg has 92 colonies
# 76.03305785123968
# SMask_Sample_6-7.jpg has 83 colonies
# 93.25842696629213
# SMask_Sample_6-8.jpg has 93 colonies
# 93.0
# SMask_Sample_6-9.jpg has 67 colonies
# 84.81012658227847
# SMask_Sample_6-10.jpg has 77 colonies
# 84.61538461538461
# SMask_Sample_6-11.jpg has 82 colonies
# 82.0
# SMask_Sample_6-12.jpg has 110 colonies
# 92.15686274509804
# SMask_Sample_6-13.jpg has 11 colonies
# 78.57142857142857
# SMask_Sample_6-14.jpg has 21 colonies
# 95.45454545454545
# SMask_Sample_6-15.jpg has 8 colonies
# 88.88888888888889
# SMask_Sample_6-16.jpg has 5 colonies
# 71.42857142857143
# SMask_Sample_6-17.jpg has 9 colonies
# 90.0
# SMask_Sample_6-18.jpg has 5 colonies
# 71.42857142857143
# SMask_Sample_7-1.jpg has 101 colonies
# 63.125
# SMask_Sample_7-2.jpg has 109 colonies
# 71.24183006535948
# SMask_Sample_7-3.jpg has 104 colonies
# 72.22222222222221
# SMask_Sample_7-4.jpg has 95 colonies
# 67.85714285714286
# SMask_Sample_7-5.jpg has 107 colonies
# 76.42857142857142
# SMask_Sample_7-6.jpg has 114 colonies
# 75.49668874172185
# SMask_Sample_7-7.jpg has 108 colonies
# 72.48322147651007
# SMask_Sample_7-8.jpg has 109 colonies
# 76.22377622377623
# SMask_Sample_7-9.jpg has 98 colonies
# 67.12328767123287
# SMask_Sample_7-10.jpg has 117 colonies
# 70.48192771084338
# SMask_Sample_7-11.jpg has 115 colonies
# 68.45238095238095
# SMask_Sample_7-12.jpg has 127 colonies
# 75.14792899408285
# SMask_Sample_7-13.jpg has 26 colonies
# 96.0
# SMask_Sample_7-14.jpg has 21 colonies
# 95.0
# SMask_Sample_7-15.jpg has 23 colonies
# 85.0
# SMask_Sample_7-16.jpg has 16 colonies
# 85.71428571428572
# SMask_Sample_7-17.jpg has 14 colonies
# 72.72727272727273
# SMask_Sample_7-18.jpg has 11 colonies
# 77.77777777777779
# SMask_Sample_8-1.jpg has 126 colonies
# 80.2547770700637
# SMask_Sample_8-2.jpg has 113 colonies
# 70.625
# SMask_Sample_8-3.jpg has 86 colonies
# 73.50427350427351
# SMask_Sample_8-4.jpg has 103 colonies
# 74.63768115942028
# SMask_Sample_8-5.jpg has 101 colonies
# 72.14285714285714
# SMask_Sample_8-6.jpg has 130 colonies
# 83.87096774193549
# SMask_Sample_8-7.jpg has 104 colonies
# 72.22222222222221
# SMask_Sample_8-8.jpg has 88 colonies
# 74.57627118644068
# SMask_Sample_8-9.jpg has 108 colonies
# 92.3076923076923
# SMask_Sample_8-10.jpg has 121 colonies
# 87.68115942028986
# SMask_Sample_8-11.jpg has 100 colonies
# 80.0
# SMask_Sample_8-12.jpg has 98 colonies
# 90.74074074074075
# SMask_Sample_8-13.jpg has 33 colonies
# 77.77777777777779
# SMask_Sample_8-14.jpg has 27 colonies
# 93.10344827586206
# SMask_Sample_8-15.jpg has 22 colonies
# 88.0
# SMask_Sample_8-16.jpg has 7 colonies
# 83.33333333333334
# SMask_Sample_8-17.jpg has 10 colonies
# 90.9090909090909
# SMask_Sample_8-18.jpg has 10 colonies
# 100.0
# SMask_Sample_9-1.jpg has 105 colonies
# 62.130177514792905
# SMask_Sample_9-2.jpg has 106 colonies
# 67.94871794871796
# SMask_Sample_9-3.jpg has 115 colonies
# 66.47398843930637
# SMask_Sample_9-4.jpg has 130 colonies
# 59.9078341013825
# SMask_Sample_9-5.jpg has 116 colonies
# 67.83625730994152
# SMask_Sample_9-6.jpg has 124 colonies
# 72.94117647058825
# SMask_Sample_9-7.jpg has 89 colonies
# 72.35772357723577
# SMask_Sample_9-8.jpg has 90 colonies
# 72.0
# SMask_Sample_9-9.jpg has 86 colonies
# 78.89908256880733
# SMask_Sample_9-10.jpg has 99 colonies
# 59.63855421686747
# SMask_Sample_9-11.jpg has 91 colonies
# 63.63636363636363
# SMask_Sample_9-12.jpg has 91 colonies
# 52.601156069364166
# SMask_Sample_9-13.jpg has 30 colonies
# 93.75
# SMask_Sample_9-14.jpg has 17 colonies
# 89.47368421052632
# SMask_Sample_9-15.jpg has 23 colonies
# 90.47619047619048
# SMask_Sample_9-16.jpg has 10 colonies
# 75.0
# SMask_Sample_9-17.jpg has 7 colonies
# 83.33333333333334
# SMask_Sample_9-18.jpg has 3 colonies
# 75.0
# SMask_Sample_10-1.jpg has 110 colonies
# 0
# SMask_Sample_10-2.jpg has 120 colonies
# 0
# SMask_Sample_10-3.jpg has 100 colonies
# 0
# SMask_Sample_10-4.jpg has 115 colonies
# 0
# SMask_Sample_10-5.jpg has 102 colonies
# 0
# SMask_Sample_10-6.jpg has 123 colonies
# 4.761904761904767
# SMask_Sample_10-7.jpg has 73 colonies
# 78.33333333333333
# SMask_Sample_10-8.jpg has 67 colonies
# 88.1578947368421
# SMask_Sample_10-9.jpg has 60 colonies
# 62.5
# SMask_Sample_10-10.jpg has 92 colonies
# 0
# SMask_Sample_10-11.jpg has 94 colonies
# 0
# SMask_Sample_10-12.jpg has 65 colonies
# 0
# SMask_Sample_10-13.jpg has 28 colonies
# 0
# SMask_Sample_10-14.jpg has 26 colonies
# 0
# SMask_Sample_10-15.jpg has 18 colonies
# 0
# SMask_Sample_10-16.jpg has 1 colonies
# 100.0
# SMask_Sample_10-17.jpg has 7 colonies
# 0
# SMask_Sample_10-18.jpg has 4 colonies
# 0
# SMask_Sample_11-1.jpg has 107 colonies
# 0
# SMask_Sample_11-2.jpg has 112 colonies
# 0
# SMask_Sample_11-3.jpg has 106 colonies
# 0
# SMask_Sample_11-4.jpg has 110 colonies
# 0
# SMask_Sample_11-5.jpg has 102 colonies
# 0
# SMask_Sample_11-6.jpg has 95 colonies
# 49.20634920634921
# SMask_Sample_11-7.jpg has 97 colonies
# 38.33333333333333
# SMask_Sample_11-8.jpg has 107 colonies
# 59.210526315789465
# SMask_Sample_11-9.jpg has 92 colonies
# 95.83333333333334
# SMask_Sample_11-10.jpg has 117 colonies
# 0
# SMask_Sample_11-11.jpg has 127 colonies
# 0
# SMask_Sample_11-12.jpg has 121 colonies
# 0
# SMask_Sample_11-13.jpg has 22 colonies
# 0
# SMask_Sample_11-14.jpg has 23 colonies
# 0
# SMask_Sample_11-15.jpg has 15 colonies
# 0
# SMask_Sample_11-16.jpg has 5 colonies
# 0
# SMask_Sample_11-17.jpg has 6 colonies
# 0
# SMask_Sample_11-18.jpg has 8 colonies
# 0
# SMask_Sample_12-1.jpg has 100 colonies
# 0
# SMask_Sample_12-2.jpg has 91 colonies
# 0
# SMask_Sample_12-3.jpg has 97 colonies
# 0
# SMask_Sample_12-4.jpg has 97 colonies
# 0
# SMask_Sample_12-5.jpg has 101 colonies
# 0
# SMask_Sample_12-6.jpg has 111 colonies
# 23.809523809523814
# SMask_Sample_12-7.jpg has 72 colonies
# 80.0
# SMask_Sample_12-8.jpg has 84 colonies
# 89.47368421052632
# SMask_Sample_12-9.jpg has 81 colonies
# 84.375
# SMask_Sample_12-10.jpg has 101 colonies
# 0
# SMask_Sample_12-11.jpg has 82 colonies
# 0
# SMask_Sample_12-12.jpg has 110 colonies
# 0
# SMask_Sample_12-13.jpg has 21 colonies
# 0
# SMask_Sample_12-14.jpg has 24 colonies
# 0
# SMask_Sample_12-15.jpg has 17 colonies
# 0
# SMask_Sample_12-16.jpg has 6 colonies
# 0
# SMask_Sample_12-17.jpg has 10 colonies
# 0
# SMask_Sample_12-18.jpg has 4 colonies
# 0
# SMask_Sample_13-1.jpg has 152 colonies
# 0
# SMask_Sample_13-2.jpg has 168 colonies
# 0
# SMask_Sample_13-3.jpg has 149 colonies
# 0
# SMask_Sample_13-4.jpg has 155 colonies
# 0
# SMask_Sample_13-5.jpg has 162 colonies
# 0
# SMask_Sample_13-6.jpg has 165 colonies
# 0
# SMask_Sample_13-7.jpg has 1 colonies
# 1.6666666666666718
# SMask_Sample_13-8.jpg has 1 colonies
# 1.3157894736842146
# SMask_Sample_13-9.jpg has 2 colonies
# 2.083333333333337
# SMask_Sample_14-1.jpg has 89 colonies
# 0
# SMask_Sample_14-2.jpg has 78 colonies
# 0
# SMask_Sample_14-3.jpg has 83 colonies
# 0
# SMask_Sample_14-4.jpg has 83 colonies
# 0
# SMask_Sample_14-5.jpg has 69 colonies
# 0
# SMask_Sample_14-6.jpg has 93 colonies
# 52.38095238095239
# SMask_Sample_14-7.jpg has 69 colonies
# 85.0
# SMask_Sample_14-8.jpg has 56 colonies
# 73.6842105263158
# SMask_Sample_14-9.jpg has 52 colonies
# 54.16666666666667
# SMask_Sample_14-10.jpg has 41 colonies
# 0
# SMask_Sample_14-11.jpg has 56 colonies
# 0
# SMask_Sample_14-12.jpg has 42 colonies
# 0
# SMask_Sample_14-13.jpg has 5 colonies
# 0
# SMask_Sample_14-14.jpg has 5 colonies
# 0
# SMask_Sample_14-15.jpg has 11 colonies
# 0
# SMask_Sample_14-16.jpg has 2 colonies
# 0.0
# SMask_Sample_14-17.jpg has 1 colonies
# 100.0
# SMask_Sample_14-18.jpg has 0 colonies
# 0.0
# SMask_Sample_15-1.jpg has 140 colonies
# 0
# SMask_Sample_15-2.jpg has 134 colonies
# 0
# SMask_Sample_15-3.jpg has 127 colonies
# 0
# SMask_Sample_15-4.jpg has 109 colonies
# 0
# SMask_Sample_15-5.jpg has 134 colonies
# 0
# SMask_Sample_15-6.jpg has 108 colonies
# 28.57142857142857
# SMask_Sample_15-7.jpg has 82 colonies
# 63.33333333333333
# SMask_Sample_15-8.jpg has 99 colonies
# 69.73684210526316
# SMask_Sample_15-9.jpg has 84 colonies
# 87.5
# SMask_Sample_15-10.jpg has 47 colonies
# 0
# SMask_Sample_15-11.jpg has 42 colonies
# 0
# SMask_Sample_15-12.jpg has 49 colonies
# 0
# SMask_Sample_15-13.jpg has 17 colonies
# 0
# SMask_Sample_15-14.jpg has 20 colonies
# 0
# SMask_Sample_15-15.jpg has 24 colonies
# 0
# SMask_Sample_15-16.jpg has 8 colonies
# 0
# SMask_Sample_15-17.jpg has 7 colonies
# 0
# SMask_Sample_15-18.jpg has 8 colonies
# 0
# SMask_Sample_16-1.jpg has 124 colonies
# 0
# SMask_Sample_16-2.jpg has 105 colonies
# 0
# SMask_Sample_16-3.jpg has 135 colonies
# 0
# SMask_Sample_16-4.jpg has 126 colonies
# 0
# SMask_Sample_16-5.jpg has 129 colonies
# 0
# SMask_Sample_16-6.jpg has 124 colonies
# 3.1746031746031744
# SMask_Sample_16-7.jpg has 86 colonies
# 56.666666666666664
# SMask_Sample_16-8.jpg has 62 colonies
# 81.57894736842105
# SMask_Sample_16-9.jpg has 60 colonies
# 62.5
# SMask_Sample_16-10.jpg has 49 colonies
# 0
# SMask_Sample_16-11.jpg has 11 colonies
# 0
# SMask_Sample_16-12.jpg has 5 colonies
# 0
# SMask_Sample_16-13.jpg has 7 colonies
# 0
# SMask_Sample_16-14.jpg has 9 colonies
# 0
# SMask_Sample_16-15.jpg has 2 colonies
# 0.0
# SMask_Sample_16-16.jpg has 12 colonies
# 0
# SMask_Sample_17-1.jpg has 51 colonies
# 0
# SMask_Sample_17-2.jpg has 51 colonies
# 0
# SMask_Sample_17-3.jpg has 51 colonies
# 0
# SMask_Sample_17-4.jpg has 52 colonies
# 0
# SMask_Sample_17-5.jpg has 54 colonies
# 0
# SMask_Sample_17-6.jpg has 50 colonies
# 79.36507936507937
# SMask_Sample_17-7.jpg has 21 colonies
# 35.0
# SMask_Sample_17-8.jpg has 13 colonies
# 17.105263157894733
# SMask_Sample_17-9.jpg has 32 colonies
# 33.333333333333336
# SMask_Sample_17-10.jpg has 28 colonies
# 0
# SMask_Sample_17-11.jpg has 36 colonies
# 0
# SMask_Sample_17-12.jpg has 25 colonies
# 0
# SMask_Sample_17-13.jpg has 5 colonies
# 0
# SMask_Sample_17-14.jpg has 3 colonies
# 0
# SMask_Sample_17-15.jpg has 11 colonies
# 0
# SMask_Sample_17-16.jpg has 11 colonies
# 0
# SMask_Sample_17-17.jpg has 11 colonies
# 0
# SMask_Sample_17-18.jpg has 4 colonies
# 0
# SMask_Sample_17-19.jpg has 13 colonies
# 0
# SMask_Sample_17-20.jpg has 8 colonies
# 0
# SMask_Sample_17-21.jpg has 13 colonies
# 0
# SMask_Sample_17-22.jpg has 30 colonies
# 0
# SMask_Sample_17-23.jpg has 26 colonies
# 0
# SMask_Sample_17-24.jpg has 19 colonies
# 0
# SMask_Sample_18-1.jpg has 86 colonies
# 0
# SMask_Sample_18-2.jpg has 83 colonies
# 0
# SMask_Sample_18-3.jpg has 80 colonies
# 0
# SMask_Sample_18-4.jpg has 78 colonies
# 0
# SMask_Sample_18-5.jpg has 73 colonies
# 0
# SMask_Sample_18-6.jpg has 72 colonies
# 85.71428571428572
# SMask_Sample_18-7.jpg has 41 colonies
# 68.33333333333333
# SMask_Sample_18-8.jpg has 35 colonies
# 46.05263157894737
# SMask_Sample_18-9.jpg has 47 colonies
# 48.958333333333336
# SMask_Sample_18-10.jpg has 42 colonies
# 0
# SMask_Sample_18-11.jpg has 55 colonies
# 0
# SMask_Sample_18-12.jpg has 51 colonies
# 0
# SMask_Sample_18-13.jpg has 13 colonies
# 0
# SMask_Sample_18-14.jpg has 19 colonies
# 0
# SMask_Sample_18-15.jpg has 17 colonies
# 0
# SMask_Sample_18-16.jpg has 18 colonies
# 0
# SMask_Sample_18-17.jpg has 19 colonies
# 0
# SMask_Sample_18-18.jpg has 22 colonies
# 0
# SMask_Sample_18-19.jpg has 6 colonies
# 0
# SMask_Sample_18-20.jpg has 5 colonies
# 0
# SMask_Sample_18-21.jpg has 3 colonies
# 0
# SMask_Sample_18-22.jpg has 4 colonies
# 0
# SMask_Sample_18-23.jpg has 2 colonies
# 0.0
# SMask_Sample_18-24.jpg has 6 colonies
# 0
# SMask_Sample_19-1.jpg has 64 colonies
# 0
# SMask_Sample_19-2.jpg has 66 colonies
# 0
# SMask_Sample_19-3.jpg has 83 colonies
# 0
# SMask_Sample_19-4.jpg has 54 colonies
# 0
# SMask_Sample_19-5.jpg has 63 colonies
# 0
# SMask_Sample_19-6.jpg has 76 colonies
# 79.36507936507937
# SMask_Sample_19-7.jpg has 49 colonies
# 81.66666666666667
# SMask_Sample_19-8.jpg has 44 colonies
# 57.89473684210527
# SMask_Sample_19-9.jpg has 46 colonies
# 47.916666666666664
# SMask_Sample_19-10.jpg has 53 colonies
# 0
# SMask_Sample_19-11.jpg has 40 colonies
# 0
# SMask_Sample_19-12.jpg has 56 colonies
# 0
# SMask_Sample_19-13.jpg has 19 colonies
# 0
# SMask_Sample_19-14.jpg has 8 colonies
# 0
# SMask_Sample_19-15.jpg has 7 colonies
# 0
# SMask_Sample_19-16.jpg has 16 colonies
# 0
# SMask_Sample_19-17.jpg has 11 colonies
# 0
# SMask_Sample_19-18.jpg has 11 colonies
# 0
# SMask_Sample_19-19.jpg has 3 colonies
# 0
# SMask_Sample_19-20.jpg has 1 colonies
# 100.0
# SMask_Sample_19-21.jpg has 4 colonies
# 0
# SMask_Sample_19-22.jpg has 5 colonies
# 0
# SMask_Sample_19-23.jpg has 3 colonies
# 0
# SMask_Sample_19-24.jpg has 6 colonies
# 0
# SMask_Sample_20-1.jpg has 8 colonies
# 0
# SMask_Sample_20-2.jpg has 10 colonies
# 0
# SMask_Sample_20-3.jpg has 12 colonies
# 26.66666666666667
# SMask_Sample_20-4.jpg has 5 colonies
# 17.85714285714286
# SMask_Sample_20-5.jpg has 9 colonies
# 20.93023255813954
# SMask_Sample_20-6.jpg has 4 colonies
# 4.347826086956519
# SMask_Sample_20-7.jpg has 45 colonies
# 44.55445544554455
# SMask_Sample_20-8.jpg has 49 colonies
# 45.79439252336449
# SMask_Sample_20-9.jpg has 52 colonies
# 11.926605504587151
# SMask_Sample_20-10.jpg has 64 colonies
# 0
# SMask_Sample_20-11.jpg has 61 colonies
# 0
# SMask_Sample_20-12.jpg has 52 colonies
# 0
# SMask_Sample_20-13.jpg has 9 colonies
# 0
# SMask_Sample_20-14.jpg has 12 colonies
# 0
# SMask_Sample_20-15.jpg has 14 colonies
# 0
# SMask_Sample_20-16.jpg has 6 colonies
# 0.0
# SMask_Sample_20-17.jpg has 17 colonies
# 0
# SMask_Sample_20-18.jpg has 11 colonies
# 0
# SMask_Sample_20-19.jpg has 12 colonies
# 0
# SMask_Sample_20-20.jpg has 20 colonies
# 0
# SMask_Sample_20-21.jpg has 8 colonies
# 0.0
# SMask_Sample_20-22.jpg has 12 colonies
# 0
# SMask_Sample_20-23.jpg has 15 colonies
# 0
# SMask_Sample_20-24.jpg has 11 colonies
# 0
# SMask_Sample_21-1.jpg has 60 colonies
# 0
# SMask_Sample_21-2.jpg has 78 colonies
# 0
# SMask_Sample_21-3.jpg has 68 colonies
# 48.88888888888889
# SMask_Sample_21-4.jpg has 76 colonies
# 0
# SMask_Sample_21-5.jpg has 83 colonies
# 6.976744186046513
# SMask_Sample_21-6.jpg has 68 colonies
# 73.91304347826086
# SMask_Sample_21-7.jpg has 58 colonies
# 57.425742574257434
# SMask_Sample_21-8.jpg has 56 colonies
# 52.33644859813084
# SMask_Sample_21-9.jpg has 52 colonies
# 11.926605504587151
# SMask_Sample_21-10.jpg has 61 colonies
# 0
# SMask_Sample_21-11.jpg has 61 colonies
# 0
# SMask_Sample_21-12.jpg has 49 colonies
# 0
# SMask_Sample_21-13.jpg has 6 colonies
# 0.0
# SMask_Sample_21-14.jpg has 5 colonies
# 33.333333333333336
# SMask_Sample_21-15.jpg has 9 colonies
# 0
# SMask_Sample_21-16.jpg has 8 colonies
# 0
# SMask_Sample_21-17.jpg has 14 colonies
# 0
# SMask_Sample_21-18.jpg has 6 colonies
# 0.0
# SMask_Sample_21-19.jpg has 4 colonies
# 66.66666666666667
# SMask_Sample_21-20.jpg has 2 colonies
# 50.0
# SMask_Sample_21-21.jpg has 3 colonies
# 75.0
# SMask_Sample_21-22.jpg has 7 colonies
# 25.0
# SMask_Sample_21-23.jpg has 4 colonies
# 100.0
# SMask_Sample_21-24.jpg has 2 colonies
# 50.0
# SMask_Sample_22-1.jpg has 36 colonies
# 0
# SMask_Sample_22-2.jpg has 42 colonies
# 0
# SMask_Sample_22-3.jpg has 37 colonies
# 82.22222222222221
# SMask_Sample_22-4.jpg has 29 colonies
# 96.42857142857143
# SMask_Sample_22-5.jpg has 35 colonies
# 81.3953488372093
# SMask_Sample_22-6.jpg has 35 colonies
# 38.04347826086957
# SMask_Sample_22-7.jpg has 12 colonies
# 11.881188118811881
# SMask_Sample_22-8.jpg has 11 colonies
# 10.280373831775702
# SMask_Sample_22-9.jpg has 5 colonies
# 1.1467889908256867
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 51
#      49 cv.drawContours(mask_org, contours, -1, (0, 255, 0), 5)
#      50 destination = os.path.join('.', 'Data', 'HCT116_Dataset', 'contour_small', filename)
# ---> 51 cv.imwrite(destination, mask_org)
#      54 ## Count the colonies based on the contours ##
#      55 counter = 0
#
# KeyboardInterrupt:

# %% [markdown]
# #### Miscellaneous Codes

# %%
# ## Split by solidity on sureFront1 ##
# '''
#     Compute solidity (area/hull_area) and split the objects based on solidity.

#     Variables:
#         contours(list): list of all object contours in the image.
#         contours_solid(list): contours of objects that do not need further segmentation.
#         contours_non_solid(list): contours of objects that need further segmentation due to bordering.

# '''
# contours, _ = cv.findContours(sureFront1_inter, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE) # detect all objects in sureFront1_inter
# contours_solid=[] # Does not need further segmentation
# contours_non_solid = [] # Need further segmentation
# for contour in contours:
#     area = cv.contourArea(contour) # find area of a contour
#     hull = cv.convexHull(contour) # find convex hull of a contour
#     hull_area = cv.contourArea(hull) # find convex hull area
#     solidity = float(area)/hull_area
#     if(solidity<0.94 and area>500): #threshold is 0.94
#         contours_non_solid.append(contour)
#     else:
#         contours_solid.append(contour)

# contours_non_solid = tuple(contours_non_solid)
# contours_solid = tuple(contours_solid)


# ## Further process the non-solid objects ##
# '''
#     Variables:
#         mask_non_solid(numpy.ndarray): new mask for storing non-solid objects
#         mask_solid(numpy.ndarray): new mask for storing solid objects
#         kernel2(numpy.ndarray): kernel specifically for smoothing and segmenting objects
#         sureFront1(numpy.ndarray): final sure foreground with all but small objects

# '''
# mask_non_solid = cv.cvtColor(np.zeros(overlay.shape, dtype=np.uint8), cv.COLOR_RGB2GRAY)
# mask_solid = cv.cvtColor(np.zeros(overlay.shape, dtype=np.uint8), cv.COLOR_RGB2GRAY)
# cv.drawContours(mask_non_solid, contours_non_solid, contourIdx=-1, color=(255, 255, 255), thickness=cv.FILLED)
# cv.drawContours(mask_solid, contours_solid, contourIdx=-1, color=(255, 255, 255), thickness=cv.FILLED) #split the mask further

# # Distance Transform on the non-solid objects
# dist_transform = cv.distanceTransform(mask_non_solid,cv.DIST_L2,5)
# _, mask_non_solid = cv.threshold(dist_transform,0.15*dist_transform.max(),255,0)
# mask_non_solid = cv.normalize(mask_non_solid, None, 255, 0, cv.NORM_MINMAX, cv.CV_8U)
# kernel2 = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
# # kernel1 = cv.getStructuringElement(cv.MORPH_CROSS,(7,7))
# # new_mask = cv.dilate(new_mask, kernel2, iterations=2)
# mask_non_solid = cv.erode(mask_non_solid, kernel2, iterations=9)
# mask_non_solid = cv.morphologyEx(mask_non_solid, cv.MORPH_CLOSE, kernel, iterations=3)
# # mask_non_solid = img_as_ubyte(mask_non_solid) # convert image to uint8 format
# # mask_solid = cv.dilate(mask_solid, kernel2, iterations=2)
# sureFront1 = cv.bitwise_or(mask_non_solid, mask_solid)




# ## Eccentricity ##
# for contour in contours:
#         # Compute moments of the contour
#         M = cv.moments(contour)
#         print(M)
#         print(awdwdsd)
#         if M['m00'] != 0:
#             eccentricity = (M['m20'] + M['m02'] + math.sqrt(( M['m20'] - M['m02'])**2 + 4 * (M['m11']**2))) / (M['m20'] + M['m02'] - math.sqrt(( M['m20'] - M['m02'])**2 + 4 * (M['m11']**2))) # https://users.cs.cf.ac.uk/Dave.Marshall/Vision_lecture/node36.html
#             cx = int(M['m10'] / M['m00'])
#             cy = int(M['m01'] / M['m00'])
#             # Draw circle at center of mass
#             cv.circle(mask, (cx, cy), 5, (0, 255, 0), -1)
#         print(eccentricity)
